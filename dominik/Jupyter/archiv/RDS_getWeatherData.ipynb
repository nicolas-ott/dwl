# %%
import requests
import psycopg2
import json
import pprint
import pandas as pd
from sqlalchemy import create_engine
import io
from datetime import date

# %%
# Package list of the Swiss open data portal
packages = 'https://opendata.swiss/api/3/action/package_list'

# %%
# Make the HTTP request
response = requests.get(packages)

# Use the json module to load CKAN's response into a dictionary
response_dict = json.loads(response.content)

# Check the contents of the response
assert response_dict['success'] is True  # make sure if response is OK
result = response_dict['result']         # extract all the packages from the response
pprint.pprint(result)                    # pretty print the list to the screen
# Out:
# ['__',
#  '__1',
#  '__10',
#  '__100',
#  '__101',
#  '__102',
#  '__103',
#  '__104',
#  '__105',
#  '__106',
#  '__107',
#  '__108',
#  '__109',
#  '__11',
#  '__110',
#  '__111',
#  '__112',
#  '__113',
#  '__114',
#  '__115',
#  '__116',
#  '__117',
#  '__118',
#  '__119',
#  '__12',
#  '__120',
#  '__121',
#  '__122',
#  '__123',
#  '__124',
#  '__125',
#  '__126',
#  '__127',
#  '__128',
#  '__129',
#  '__13',
#  '__130',
#  '__131',
#  '__132',
#  '__133',
#  '__134',
#  '__135',
#  '__136',
#  '__137',
#  '__138',
#  '__139',
#  '__14',
#  '__140',
#  '__142',
#  '__143',
#  '__147',
#  '__148',
#  '__15',
#  '__150',
#  '__151',
#  '__152',
#  '__158',
#  '__159',
#  '15-jahresverbrauch',
#  '15-jahresverbrauch-ha',
#  '__16',
#  '__160',
#  '__161',
#  '__162',
#  '__163',
#  '__166',
#  '__167',
#  '__168',
#  '__169',
#  '__17',
#  '__170',
#  '__171',
#  '__172',
#  '__173',
#  '__174',
#  '__175',
#  '__176',
#  '__177',
#  '__178',
#  '__179',
#  '__18',
#  '__180',
# ...

# %% [markdown]
# ### Täglich aktualisierte Meteodaten

# %% [markdown]
# #### Extract all csv files from API

# %%
# Specify the package you are interested in:
package = 'taglich-aktualisierte-meteodaten-seit-1992'

# %%
# Base url for package information. This is always the same.
base_url = 'https://opendata.swiss/api/3/action/package_show?id='

# Construct the url for the package of interest
package_information_url = base_url + package

# Make the HTTP request
package_information = requests.get(package_information_url)

# Use the json module to load CKAN's response into a dictionary
package_dict = json.loads(package_information.content)

# Check the contents of the response.
assert package_dict['success'] is True  # again make sure if response is OK
package_dict = package_dict['result']   # we only need the 'result' part from the dictionary
pprint.pprint(package_dict)             # pretty print the package information to screen
# Out:
# {'accrual_periodicity': 'http://purl.org/cld/freq/daily',
#  'author': 'Messung Luftqualität, Umwelt- und Gesundheitsschutz, Gesundheits- '
#            'und Umweltdepartement',
#  'author_email': None,
#  'contact_points': [{'email': 'opendata@zuerich.ch',
#                      'name': 'Open Data Zürich'}],
#  'creator_user_id': 'af084126-f711-4016-a585-70354e997796',
#  'description': {'de': '\n'
#                        'Der Datensatz umfasst **Tageswerte** **ab 1992 bis zum '
#                        'aktuellen Vortag** aufgeteilt in Jahresdateien. Darin '
#                        'enthalten sind die Stationen Stampfenbachstrasse, '
#                        'Schimmelstrasse und Rosengartenstrasse. Gemessen wird '
#                        'der Luftdruck (p), die Niederschlagsdauer (RainDur), '
#                        'die Globalstrahlung (StrGlo), die Temperatur (T) und '
#                        'die relative Luftfeuchtigkeit (Hr). Die Winddaten '
# ...

# %%
package_dict['resources'][0]['url'][-25:-4]
# Out:
# 'ugz_ogd_meteo_d1_2017'

# %%
# Get the relevant metadata for the data from the dictionary
df_sources = pd.DataFrame({'year':[],'filename':[],'package_id': [], 'url': [],'uri': [],'format': []})

for ele in package_dict['resources']:
    to_append = [ele['url'][-8:-4],ele['url'][-25:-4],ele['package_id'], ele['url'],ele['uri'],ele['format']]
    df_sources.loc[len(df_sources)] = to_append
    
df_sources =  df_sources[df_sources['format']=="CSV"] #only keep csv files in the dataframe
df_sources['year'] = df_sources['year'].astype(int) # convert year to int

# %%
df_sources
# Out:
#     year               filename                            package_id  \
# 0   2017  ugz_ogd_meteo_d1_2017  20f7c6d9-57ad-4381-9964-51924471a987
# 1   2009  ugz_ogd_meteo_d1_2009  20f7c6d9-57ad-4381-9964-51924471a987
# 3   1992  ugz_ogd_meteo_d1_1992  20f7c6d9-57ad-4381-9964-51924471a987
# 4   2004  ugz_ogd_meteo_d1_2004  20f7c6d9-57ad-4381-9964-51924471a987
# 5   1999  ugz_ogd_meteo_d1_1999  20f7c6d9-57ad-4381-9964-51924471a987
# 6   1994  ugz_ogd_meteo_d1_1994  20f7c6d9-57ad-4381-9964-51924471a987
# 7   1995  ugz_ogd_meteo_d1_1995  20f7c6d9-57ad-4381-9964-51924471a987
# 8   2013  ugz_ogd_meteo_d1_2013  20f7c6d9-57ad-4381-9964-51924471a987
# 9   2010  ugz_ogd_meteo_d1_2010  20f7c6d9-57ad-4381-9964-51924471a987
# 10  1997  ugz_ogd_meteo_d1_1997  20f7c6d9-57ad-4381-9964-51924471a987
# 11  2014  ugz_ogd_meteo_d1_2014  20f7c6d9-57ad-4381-9964-51924471a987
# 12  2020  ugz_ogd_meteo_d1_2020  20f7c6d9-57ad-4381-9964-51924471a987
# ...

# %% [markdown]
# Extract urls for historic and current csv files

# %%
current_year = date.today().year # creating a variable with the current year

# %%
current_year_file_path = df_sources.loc[df_sources['year'] == current_year]["url"].values[0]

# %%
historic_file_paths = []

for x in df_sources.loc[df_sources['year'] != current_year]["url"]:
    historic_file_paths.append(x)

# %%
# Out:
# ['https://data.stadt-zuerich.ch/dataset/ugz_meteodaten_tagesmittelwerte/download/ugz_ogd_meteo_d1_2017.csv',
#  'https://data.stadt-zuerich.ch/dataset/ugz_meteodaten_tagesmittelwerte/download/ugz_ogd_meteo_d1_2009.csv',
#  'https://data.stadt-zuerich.ch/dataset/ugz_meteodaten_tagesmittelwerte/download/ugz_ogd_meteo_d1_1992.csv',
#  'https://data.stadt-zuerich.ch/dataset/ugz_meteodaten_tagesmittelwerte/download/ugz_ogd_meteo_d1_2004.csv',
#  'https://data.stadt-zuerich.ch/dataset/ugz_meteodaten_tagesmittelwerte/download/ugz_ogd_meteo_d1_1999.csv',
#  'https://data.stadt-zuerich.ch/dataset/ugz_meteodaten_tagesmittelwerte/download/ugz_ogd_meteo_d1_1994.csv',
#  'https://data.stadt-zuerich.ch/dataset/ugz_meteodaten_tagesmittelwerte/download/ugz_ogd_meteo_d1_1995.csv',
#  'https://data.stadt-zuerich.ch/dataset/ugz_meteodaten_tagesmittelwerte/download/ugz_ogd_meteo_d1_2013.csv',
#  'https://data.stadt-zuerich.ch/dataset/ugz_meteodaten_tagesmittelwerte/download/ugz_ogd_meteo_d1_2010.csv',
# ...

# %%
# merging csv files into one single dataframe
df = pd.concat(
    map(pd.read_csv, list(df_sources["url"])), ignore_index=True)

# %%
# Out:
#                      Datum                 Standort Parameter Intervall  \
# 0    1994-01-01T00:00+0100  Zch_Stampfenbachstrasse    StrGlo        d1
# 1    1994-01-01T00:00+0100  Zch_Stampfenbachstrasse         T        d1
# 2    1994-01-01T00:00+0100  Zch_Stampfenbachstrasse         p        d1
# 3    1994-01-01T00:00+0100  Zch_Stampfenbachstrasse  T_max_h1        d1
# 4    1994-01-02T00:00+0100  Zch_Stampfenbachstrasse    StrGlo        d1
# ..                     ...                      ...       ...       ...
# 495  1994-05-04T00:00+0100  Zch_Stampfenbachstrasse  T_max_h1        d1
# 496  1994-05-05T00:00+0100  Zch_Stampfenbachstrasse    StrGlo        d1
# 497  1994-05-05T00:00+0100  Zch_Stampfenbachstrasse         T        d1
# 498  1994-05-05T00:00+0100  Zch_Stampfenbachstrasse         p        d1
# 499  1994-05-05T00:00+0100  Zch_Stampfenbachstrasse  T_max_h1        d1
#
#     Einheit    Wert     Status
# 0      W/m2   27.09  bereinigt
# 1        °C    3.60  bereinigt
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86233 entries, 0 to 86232
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Datum      86233 non-null  object
#  1   Standort   86233 non-null  object
#  2   Parameter  86233 non-null  object
#  3   Intervall  86233 non-null  object
#  4   Einheit    86233 non-null  object
#  5   Wert       85140 non-null  float64
#  6   Status     86233 non-null  object
# dtypes: float64(1), object(6)
# memory usage: 4.6+ MB

# %%
#df = df.astype(object) #use same type for all columns

# %% [markdown]
# #### Initial Load into aws database

# %%
try: 
    conn = psycopg2.connect(host="trunks.cwh7dj4q8zyj.us-east-1.rds.amazonaws.com",
                            dbname="Trunks",
                            user="trunks",
                            password="Corn5!!!")
except psycopg2.Error as e:
    print("Error: Could not make connection to the Postgres database")
    print(e)

# %%
try: 
    cur = conn.cursor()
except psycopg2.Error as e: 
    print("Error: Could not get curser to the Database")
    print(e)
    
# Auto commit is very important
conn.set_session(autocommit=True)

# %%
#cur.execute("CREATE TABLE IF NOT EXISTS weather_daily (Datum varchar(255),Standort varchar(255),Parameter varchar(255),Intervall varchar(255),Einheit varchar(255),Wert int,Status varchar(255));")

# %%
conn_string = 'postgresql://trunks:Corn5!!!@trunks.cwh7dj4q8zyj.us-east-1.rds.amazonaws.com/Trunks'
  
db = create_engine(conn_string)
conn = db.connect()

# write df to db
df.to_sql('weather_daily', con=conn, if_exists='replace',
          index=False)
conn = psycopg2.connect(conn_string
                        )
conn.autocommit = True
cursor = conn.cursor()

# %%
cur.close()
conn.close()

# %% [markdown]
# ### Stündlich aktualisierte Meteodaten

# %% [markdown]
# #### Extract all csv files from API

# %%
# Specify the package you are interested in:
package ='stundlich-aktualisierte-meteodaten-seit-1992'

# %%
# Base url for package information. This is always the same.
base_url = 'https://opendata.swiss/api/3/action/package_show?id='

# Construct the url for the package of interest
package_information_url = base_url + package

# Make the HTTP request
package_information = requests.get(package_information_url)

# Use the json module to load CKAN's response into a dictionary
package_dict = json.loads(package_information.content)

# Check the contents of the response.
assert package_dict['success'] is True  # again make sure if response is OK
package_dict = package_dict['result']   # we only need the 'result' part from the dictionary
#pprint.pprint(package_dict)             # pretty print the package information to screen

# %%
# Get the relevant metadata for the data from the dictionary
df_sources = pd.DataFrame({'package_id': [], 'url': [],'uri': [],'format': []})

for ele in package_dict['resources']:
    to_append = [ele['package_id'], ele['url'],ele['uri'],ele['format']]
    df_sources.loc[len(df_sources)] = to_append
    
df_sources =  df_sources[df_sources['format']=="CSV"] #only keep csv files in the dataframe

# %%
# merging csv files into one single dataframe
df = pd.concat(
    map(pd.read_csv, list(df_sources["url"])), ignore_index=True)

# %% [markdown]
# #### Initial Load into aws database

# %%
try: 
    conn = psycopg2.connect(host="trunks.cwh7dj4q8zyj.us-east-1.rds.amazonaws.com",
                            dbname="Trunks",
                            user="trunks",
                            password="Corn5!!!")
except psycopg2.Error as e: 
    print("Error: Could not make connection to the Postgres database")
    print(e)

# %%
try: 
    cur = conn.cursor()
except psycopg2.Error as e: 
    print("Error: Could not get curser to the Database")
    print(e)
    
# Auto commit is very important
conn.set_session(autocommit=True)

# %%
conn_string = 'postgresql://trunks:Corn5!!!@trunks.cwh7dj4q8zyj.us-east-1.rds.amazonaws.com/Trunks'
  
db = create_engine(conn_string)
conn = db.connect()

# write df to db
df.to_sql('weather_hourly', con=conn, if_exists='replace',
          index=False)
conn = psycopg2.connect(conn_string
                        )
conn.autocommit = True
cursor = conn.cursor()

# %%
cur.close()
conn.close()
